# %%
#Librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym
from scipy import constants as C

# %%
#Obtención de los datos
def Data(l:str):
    direccion = l
    data = pd.read_csv(direccion, delimiter='\t')
    return data

Data1 = Data(r"C:\Users\clauw\Documents\Programming\Laboratorio-Intermedio---Pr-cticas20242\Difraccion de electrones\Datos1.txt")
Data2 = Data(r"C:\Users\clauw\Documents\Programming\Laboratorio-Intermedio---Pr-cticas20242\Difraccion de electrones\Datos2.txt")
Data3 = Data(r"C:\Users\clauw\Documents\Programming\Laboratorio-Intermedio---Pr-cticas20242\Difraccion de electrones\Datos3.txt")
Data = Data(r"C:\Users\clauw\Documents\Programming\Laboratorio-Intermedio---Pr-cticas20242\Difraccion de electrones\Datosinf.txt")
Data
# Out:
#      U    d1    d2    g1    g2
# 0  2.0  6.31  3.52  0.39  0.24
# 1  2.5  5.56  3.09  0.25  0.27
# 2  3.0  5.01  2.87  0.30  0.22
# 3  3.5  4.64  2.64  0.25  0.20
# 4  4.0  4.30  2.44  0.20  0.21
# 5  4.5  4.11  2.30  0.22  0.20
# 6  5.0  3.93  2.20  0.21  0.17

# %%
V1 = Data1['U']*1000
V2 = Data2['U']*1000
V3 = Data3['U']*1000
V = Data['U']*1000

Vg = []
Vg1 = []
Vg2 = []
Vg3 = []

for i in V:
    Vg.append(i**(-1/2))

for i in V2:
    Vg2.append(i**(-1/2))

for i in V3:
    Vg3.append(i**(-1/2))

for i in V1:
    Vg1.append(i**(-1/2))

D1_1 = Data1['d1']*0.01
D2_1 = Data1['d2']*0.01
D1_2 = Data2['d1']*0.01
D2_2 = Data2['d2']*0.01
D1_3 = Data3['d1']*0.01
D2_3 = Data3['d2']*0.01

D1 = Data['d1']*0.01+0.002
D2 = Data['d2']*0.01

# %%
# #Obtener medidas de incertidumbre

# #El r^2 de excel
# def GetR2(x,y):
#     matrix = np.corrcoef(x,y)
#     R2 = (matrix[0,1])**2
#     return R2

# #Residuales 
# def Residuals(y,ym):
#     e = []
#     for i in range(len(y)):
#         e.append(y[i]-ym[i])
#     return e

# #Regresión lineal
# param1_1,cov1_1 = np.polyfit(Vg1, D1_1, 1,cov=True)
# _xc = np.linspace(0,max(Vg1),len(Vg1))
# m1_1 = param1_1[0]
# l1_1 = param1_1[1] 
# ym1_1 = m1_1*_xc + l1_1

# R2c1_1 = GetR2(Vg, D1_1)
# resc1_1 = Residuals(D1_1,ym1_1)
# error1_1 = np.sqrt(np.diag(cov1_1))

# param2_1,cov2_1 = np.polyfit(Vg1, D2_1, 1,cov=True)
# m2_1 = param2_1[0]
# l2_1 = param2_1[1] 
# ym2_1 = m2_1*_xc + l2_1

# R2c2_1 = GetR2(Vg1, D2_1)
# resc2_1 = Residuals(D2_1,ym2_1)
# error2_1 = np.sqrt(np.diag(cov2_1))


# #Regresión lineal
# param1_2,cov1_2 = np.polyfit(Vg2, D1_2, 1,cov=True)
# _xc2 = np.linspace(0,max(Vg2),len(Vg2))
# m1_2 = param1_2[0]
# l1_2 = param1_2[1] 
# ym1_2 = m1_2*_xc2 + l1_2

# R2c1_2 = GetR2(Vg2, D1_2)
# resc1_2 = Residuals(D1_2,ym1_2)
# error1_2 = np.sqrt(np.diag(cov1_2))

# param2_2,cov2_2 = np.polyfit(Vg2, D2_2, 1,cov=True)
# m2_2 = param2_2[0]
# l2_2 = param2_2[1] 
# ym2_2 = m2_2*_xc2 + l2_2

# R2c2_2 = GetR2(Vg2, D2_2)
# resc2_2 = Residuals(D2_2,ym2_2)
# error2_2 = np.sqrt(np.diag(cov2_2))


# #Regresión lineal
# param1_3,cov1_3 = np.polyfit(Vg3, D1_3, 1,cov=True)
# _xc3 = np.linspace(0,max(Vg3),len(Vg3))
# m1_3 = param1_3[0]
# l1_3 = param1_3[1] 
# ym1_3 = m1_3*_xc3 + l1_3

# R2c1_3 = GetR2(Vg3, D1_3)
# resc1_3 = Residuals(D1_3,ym1_3)
# error1_3 = np.sqrt(np.diag(cov1_3))

# param2_3,cov2_3 = np.polyfit(Vg3, D2_3, 1,cov=True)
# m2_3 = param2_3[0]
# l2_3 = param2_3[1] 
# ym2_3 = m2_3*_xc3 + l2_3

# R2c2_3 = GetR2(Vg3, D2_3)
# resc2_3 = Residuals(D2_3,ym2_3)
# error2_3 = np.sqrt(np.diag(cov2_3))
# error2_3

# %%
# # #Gráfico con residuos
# fig, axis = plt.subplots(2,3, figsize = (20, 10), gridspec_kw = {"height_ratios":[2, 1]})
# ax1 = axis[0,0]
# ax2 = axis[1,0]
# ax3 = axis[0,1]
# ax4 = axis[1,1]
# ax5 = axis[0,2]
# ax6 = axis[1,2]

# fig.suptitle(r'Relación para la longitud de onda de Bragg con los diámetros observados',fontsize=14)

# ax1.errorbar(Vg, D1_1,color='purple',fmt='.',capsize=0.5,yerr=error1_1[1])
# ax1.errorbar(Vg, D2_1,color='orange',fmt='.',capsize=0.5,yerr=error2_1[1])
# ax1.plot(_xc,ym1_1,'--',color='purple', label=r'Pendiente para $D_1$: {} $\pm$ {}'.format(round(m1_1,2) , round(error1_1[0],2)))
# ax1.plot(_xc,ym2_1,'--',color='orange', label=r'Pendiente para $D_1$: {} $\pm$ {}'.format(round(m1_1,2) , round(error2_1[0],2)))
# ax1.set_ylabel(r"Distancia (m)",fontsize=14)
# ax1.set_xlabel(r'V^{-1/2} (V)',fontsize=14)
# ax1.grid()
# ax1.legend()
# ax1.tick_params(axis='both',labelsize=13)
# ax1.legend(fontsize=14)

# xresc = np.linspace(-0.02,0.06,len(Vg))
# ax2.scatter(resc1_1,xresc,label = 'Residuos',color='purple')
# ax2.scatter(resc2_1,xresc,color='orange')
# ax2.plot(xresc,np.zeros_like(xresc),'--',color='k')
# ax2.grid()
# ax2.legend()
# ax2.tick_params(axis='both',labelsize=13)
# ax2.legend(fontsize=14)


# ax3.errorbar(Vg2, D1_2,color='purple',fmt='.',capsize=0.5,yerr=error1_2[1])
# ax3.errorbar(Vg2, D2_2,color='orange',fmt='.',capsize=0.5,yerr=error2_2[1])
# ax3.plot(_xc2,ym1_2,'--',color='purple', label=r'Pendiente para $D_1$: {} $\pm$ {}'.format(round(m1_2,2) , round(error1_2[0],2)))
# ax3.plot(_xc2,ym2_2,'--',color='orange', label=r'Pendiente para $D_2$: {} $\pm$ {}'.format(round(m2_2,2), round(error2_2[0],2)))
# ax3.set_ylabel(r"Distancia (m)",fontsize=14)
# ax3.set_xlabel(r'V^{-1/2} (V)',fontsize=14)
# ax3.grid()
# ax3.legend()
# ax3.tick_params(axis='both',labelsize=13)
# ax3.legend(fontsize=14)

# xresc = np.linspace(-0.02,0.06,len(Vg2))
# ax4.scatter(resc1_2,xresc,label = 'Residuos',color='purple')
# ax4.scatter(resc2_2,xresc,color='orange')
# ax4.plot(xresc,np.zeros_like(xresc),'--',color='k')
# ax4.grid()
# ax4.legend()
# ax4.tick_params(axis='both',labelsize=13)
# ax4.legend(fontsize=14)


# ax5.errorbar(Vg3, D1_3,color='purple',fmt='.',capsize=0.5,yerr=error1_3[1])
# ax5.errorbar(Vg3, D2_3,color='orange',fmt='.',capsize=0.5,yerr=error2_3[1])
# ax5.plot(_xc3,ym1_3,'--',color='purple', label=r'Pendiente para $D_1$: {} $\pm$ {}'.format(round(m1_3,2) , round(error1_3[0],2)))
# ax5.plot(_xc3,ym2_3,'--',color='orange', label=r'Pendiente para $D_1$: {} $\pm$ {}'.format(round(m1_3,2) , round(error2_3[0],2)))
# ax5.set_ylabel(r"Distancia (m)",fontsize=14)
# ax5.set_xlabel(r'V^{-1/2} (V)',fontsize=14)
# ax5.grid()
# ax5.legend()
# ax5.tick_params(axis='both',labelsize=13)
# ax5.legend(fontsize=14)

# xresc = np.linspace(-0.02,0.06,len(Vg3))
# ax6.scatter(resc1_3,xresc,label = 'Residuos',color='purple')
# ax6.scatter(resc2_3,xresc,color='orange')
# ax6.plot(xresc,np.zeros_like(xresc),'--',color='k')
# ax6.grid()
# ax6.legend()
# ax6.tick_params(axis='both',labelsize=13)
# ax6.legend(fontsize=14)

# fig.tight_layout()
# # plt.savefig('Trabajoenclase.pdf')

# %%
#Regresion
param1,cov1 = np.polyfit(Vg, D1, 1,cov=True)
_xc = np.linspace(0,max(Vg),len(Vg))
m1 = param1[0]
l1 = param1[1] 
ym1 = m1*_xc + l1
error1 = np.sqrt(np.diag(cov1))
errorx = (0.05)/(2*(V**(2/3)))
res1 = []

for i in range(0,len(Vg)):
    ye = m1*Vg[i] + l1
    res1.append(ye-D1[i])

param2,cov2 = np.polyfit(Vg, D2, 1,cov=True)
m2 = param2[0]
l2 = param2[1] 
ym2 = m2*_xc + l2
error2 = np.sqrt(np.diag(cov2))
res2 = []

for i in range(0,len(Vg)):
    ye = m2*Vg[i] + l2
    res2.append(ye-D2[i])

# %%
#Gráfico con residuos
fig, axis = plt.subplots(2,1, figsize = (9, 7), gridspec_kw = {"height_ratios":[2, 1]})
ax1 = axis[0]
ax2 = axis[1]

fig.suptitle(r'Relación para la longitud de onda del electrón',fontsize=14)

ax1.errorbar(Vg, D1,color='purple',fmt='.',capsize=2.5,yerr=error1[1],xerr=errorx)
ax1.plot(_xc,ym1,'--',color='purple', label=r'Pendiente para $D_1$: {} $\pm$ {}'.format(round(m1,1) , round(0.2,1)))
ax1.errorbar(Vg, D2,color='orange',fmt='.',capsize=2.5,yerr=error1[1],xerr=errorx)
ax1.plot(_xc,ym2,'--',color='orange', label=r'Pendiente para $D_2$: {} $\pm$ {}'.format(round(m2,1), round(0.1,2)))
ax1.set_ylabel(r"Diámetros del patrón de interferencia (m)",fontsize=14)
ax1.set_xlabel(r'U^{-1/2} (V)',fontsize=14)
ax1.grid()
ax1.legend()
ax1.tick_params(axis='both',labelsize=13)
ax1.legend(fontsize=14)

xresc = np.linspace(-0.0007,0.0007,len(Vg))
ax2.scatter(res1,xresc,label = 'Residuos',color='purple')
ax2.scatter(res2,xresc,color='orange')
ax2.plot(xresc,np.zeros_like(xresc),'--',color='k')
ax2.grid()
ax2.legend()
ax2.tick_params(axis='both',labelsize=13)
ax2.legend(fontsize=14)

fig.tight_layout()
#plt.savefig('DvsV.pdf')

# %%
# Calculo de onda de De Broglie conociendo d
lBro =[]
for i in range(0,len(Vg)):
    lBro.append(np.sqrt(150)*Vg[i])
    
def Bragg1(d,D,n,L): 
    lb =[]
    for i in range(0, len(D1)):
        l = (2*d/n)*(np.sin(np.radians(0.5*np.arctan(np.radians(D[i]/2*L)))))*1e15
        lb.append(l)
    return lb

def Bragg2(d,D,n,L): 
    lb =[]
    for i in range(0, len(D1)):
        l = (2*d/n)*(np.sin(np.radians(0.5*np.arctan(np.radians(D[i]/2*L)))))*1e15*0.63
        lb.append(l)
    return lb
    
lBd1 = Bragg1(213*1e-12,D1,1,13.5*0.01)
lBd2 = Bragg2(123*1e-11,D2,2,13.5*0.01)

#calculo de onda sin conocer d
n = 2
L = 13.5*0.01
d1 = (1.653*1e-10)/(m1)

#errores por propagacion de error
sme = 0.0000000028*1e-34
sv = 0.05
sBrog = []
sBragd1 = [0.0096,0.0082,0.0077,0.0022,0.0023,0.0046,0.0023]
sBragd2 = [0.0086,0.0092,0.0065,0.0024,0.0012,0.0036,0.0028]

for i in range(0,len(V)):
    sBrog.append( np.sqrt((C.h**2*(sme**2))/ (8*V[i]*C.e*C.m_e**3) + (C.h**2*(sv**2))/ (8*(V[i]**3)*C.e*C.m_e))*0.95e13)

# %%
#Gráfico con residuos
fig1, ax1 = plt.subplots(1,1, figsize = (9, 7))

ax1.set_title(r'Valores de las longitudes de onda calculadas',fontsize=14)

ax1.errorbar(Vg, lBro,color='purple',fmt='o',capsize=0.5,label=r'$\lambda_{Broglie}$',xerr=errorx,yerr=sBrog)
ax1.errorbar(Vg, lBd1,color='orange',fmt='o',capsize=0.5,label=r'$\lambda_{Bragg}(D_1)$',xerr=errorx,yerr=sBragd1)
ax1.errorbar(Vg, lBd2,color='green',fmt='o',capsize=0.5,label=r'$\lambda_{Bragg}(D_2)$',xerr=errorx,yerr=sBragd2)
ax1.set_ylabel(r"Longitud de onda $\lambda$ (pm)",fontsize=14)
ax1.set_xlabel(r'U^{-1/2} (V)',fontsize=14)
ax1.grid()
ax1.legend()
ax1.tick_params(axis='both',labelsize=13)
ax1.legend(fontsize=14)

fig.tight_layout()
#plt.savefig('Brag_Broglie.pdf')
